# %%
# %matplotlib inline
import torch
import torchvision
from IPython import display
from torch.utils import data
from torchvision import transforms
from d2l import torch as d2l

# %%
y = torch.tensor([0, 2])
y_hat = torch.tensor([[0.1, 0.3, 0.6], [0.3, 0.2, 0.5]])
y_hat[[0, 1], y]
y_hat = y_hat.argmax(axis=1)

# %%
y_hat
# Out:
# tensor([2, 2])

# %%
def accuracy(y_hat, y):
    if len(y_hat.shape) > 1 and y_hat.shape[1] > 1:
        y_hat = y_hat.argmax(axis=1)
    cmp = y_hat.type(y.dtype) == y
    return float(cmp.type(y.dtype).sum())

# %%
accuracy(y_hat, y) / len(y)
# Out:
# 0.5

# %%
# test relu
x = torch.arange(-8.0, 8.0, 0.1, requires_grad=True)
y = torch.relu(x)
d2l.plot(x.detach(), y.detach(), 'x', 'relu(x)', figsize=(5, 2.5))

# %%
# hidden_state的形状为(num_layers,batch_size,num_hiddens)
hidden_state = torch.normal(0, 1, (2, 3, 4))
hidden_state, hidden_state[-1]
# Out:
# (tensor([[[ 0.4500,  0.5955, -1.8238, -0.5610],
#           [ 0.3171, -0.2110, -0.6813, -0.2544],
#           [-0.0915, -0.6873, -0.2273, -1.2865]],
#
#          [[ 0.4508, -1.8402,  0.4990, -1.4670],
#           [-0.3883, -0.5200, -0.2317,  0.2406],
#           [-0.7983,  2.5526,  0.7188,  2.2662]]]),
#  tensor([[ 0.4508, -1.8402,  0.4990, -1.4670],
#          [-0.3883, -0.5200, -0.2317,  0.2406],
#          [-0.7983,  2.5526,  0.7188,  2.2662]]))

# %%
query = torch.unsqueeze(hidden_state[-1], dim=1)

# %%
query.shape, query
# Out:
# (torch.Size([3, 1, 4]),
#  tensor([[[ 0.4508, -1.8402,  0.4990, -1.4670]],
#
#          [[-0.3883, -0.5200, -0.2317,  0.2406]],
#
#          [[-0.7983,  2.5526,  0.7188,  2.2662]]]))
