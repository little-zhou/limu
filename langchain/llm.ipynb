# %%
# pip install langchain

# %%
import getpass
import os

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = "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"

# %%
# 1. 设置 API 密钥
os.environ["GOOGLE_API_KEY"] = "AIzaSyDasOR22yOTEF8Qbr_GhA5VyLnXDUTeMpc"

# 2. 注意：导入 "genai" 包
from langchain_google_genai import ChatGoogleGenerativeAI

# 3. 注意：使用 ChatGoogleGenerativeAI 类
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# 现在 model 可以正常工作了
print(model.invoke("你好").content)

# %%
# model

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage(content="Translate the following from English into Italian"),
    HumanMessage(content="hi!"),
]

model.invoke(messages)
# Out:
# AIMessage(content='Ciao!', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--1349634c-da4d-403e-831e-4e6a1726d754-0', usage_metadata={'input_tokens': 10, 'output_tokens': 36, 'total_tokens': 46, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 34}})

# %%
# 输出解析器
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()
# 把模型的返回结果交给解析器
result = model.invoke(messages)
parser.invoke(result)
# Out:
# 'Ciao!'

# %%
# 链式调用，这意味着模型与此输出解析器"链式"连接,通过|轻松创建链。
chain = model | parser
chain.invoke(messages)
# Out:
# 'Ciao!'

# %%
# 提示词模板 将用户原始输入转换为传给语言模型的消息列表
from langchain_core.prompts import ChatPromptTemplate

# %%
system_template = "Translate the following into {language}:"

# %%
prompt_template = ChatPromptTemplate.from_messages(
    [("system", system_template), ("user", "{text}")]
)

# %%
prompt_template

# %%
result = prompt_template.invoke({"language": "italian", "text": "hi"})
result

# %%
result.to_messages()

# %%
# 使用LCEL连接组件,LangChain表达式
chain = prompt_template | model | parser
chain.invoke({"language": "italian", "text": "hi"})
